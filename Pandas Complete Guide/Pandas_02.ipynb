# %% [markdown]
# # 01-How to find the version

# %%
import pandas as pd
pd.__version__
# Out:
# '2.3.3'

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit                : 9c8bc3e55188c8aff37207a74f1dd144980b8874
# python                : 3.13.5
# python-bits           : 64
# OS                    : Windows
# OS-release            : 11
# Version               : 10.0.26200
# machine               : AMD64
# processor             : AMD64 Family 23 Model 96 Stepping 1, AuthenticAMD
# byteorder             : little
# LC_ALL                : None
# LANG                  : None
# LOCALE                : English_Pakistan.1252
#
# pandas                : 2.3.3
# numpy                 : 2.2.6
# pytz                  : 2025.2
# dateutil              : 2.9.0.post0
# pip                   : 25.1.1
# Cython                : None
# sphinx                : None
# IPython               : 9.10.0
# adbc-driver-postgresql: None
# adbc-driver-sqlite    : None
# bs4                   : None
# blosc                 : None
# bottleneck            : None
# dataframe-api-compat  : None
# ...

# %% [markdown]
# # 02-Make a Dataframe

# %%
df=pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
print(df)
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
# use numpy to create a dataframe
import numpy as np
arr=np.array([[1, 2, 3], [4, 5, 6]])
df2=pd.DataFrame(arr, columns=['A', 'B', 'C'])
print(df2)
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %% [markdown]
# # 03-Rename the column

# %%
df2
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %%
df2.rename(columns={'A': 'col_a', 'B': 'col_b', 'C': 'col_c'}, inplace=True)
print(df2)
# Out:
#    col_a  col_b  col_c
# 0      1      2      3
# 1      4      5      6

# %%
# add prefix to column names
df2.add_prefix('col_')
# add suffix to column names
df2.add_suffix('_col')
# Out:
#    col_a_col  col_b_col  col_c_col
# 0          1          2          3
# 1          4          5          6

# %%
df.columns=['col_a', 'col_b']
print(df)
# Out:
#    col_a  col_b
# 0      1      4
# 1      2      5
# 2      3      6

# %% [markdown]
# # 4-Using Template Data.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
df=sns.load_dataset('titanic')
df.head()
# df2=sns.load_dataset('tips')
# df2.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# saving a dataset to csv
df.to_csv('titanic.csv', index=False)
# saving a dataset to excel
df.to_excel('titanic.xlsx', index=False)

# %% [markdown]
# # 5-Using your own data

# %%
import pandas as pd
df=pd.read_csv('titanic.csv')
df.head()
# df.tail()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # 6-Reverse row order

# %%
import pandas as pd
df=pd.read_csv('titanic.csv')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.loc[::-1]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 0           0       3    male  22.0      1      0   7.2500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.loc[::-1].reset_index(drop=True)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  32.0      0      0   7.7500        Q   Third
# 1           1       1    male  26.0      0      0  30.0000        C   First
# 2           0       3  female   NaN      1      2  23.4500        S   Third
# 3           1       1  female  19.0      0      0  30.0000        S   First
# 4           0       2    male  27.0      0      0  13.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       3    male  35.0      0      0   8.0500        S   Third
# 887         1       1  female  35.0      1      0  53.1000        S   First
# 888         1       3  female  26.0      0      0   7.9250        S   Third
# 889         1       1  female  38.0      1      0  71.2833        C   First
# 890         0       3    male  22.0      1      0   7.2500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # Reduce Data size

# %%
df=sns.load_dataset('titanic')
df.shape
# Out:
# (891, 15)

# %% [markdown]
# # Copy Data for clipboard

# %%
import pandas as pd
df=pd.read_clipboard()
df
# Out:
#     0     7.25  S   Third    man   TRUE
# 0   0  71.2833  C   First  woman  False
# 1   0   7.9250  S   Third  woman  False
# 2   0  53.1000  S   First  woman  False
# 3   0   8.0500  S   Third    man   True
# 4   0   8.4583  Q   Third    man   True
# 5   0  51.8625  S   First    man   True
# 6   1  21.0750  S   Third  child  False
# 7   2  11.1333  S   Third  woman  False
# 8   0  30.0708  C  Second  child  False
# 9   1  16.7000  S   Third  child  False
# 10  0  26.5500  S   First  woman  False
# 11  0   8.0500  S   Third    man   True
# 12  5  31.2750  S   Third    man   True
# 13  0   7.8542  S   Third  child  False

# %% [markdown]
# # Split dataframe in two subsets

# %%
import pandas as pd
import seaborn as sns
df=sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.shape
# Out:
# (891, 15)

# %%
df.size
# Out:
# 13365

# %%
len(df)
# Out:
# 891

# %%
from random import random
kashti_1=df.sample(frac=0.5, random_state=1)
kashti_1.shape
# Out:
# (446, 15)

# %%
kashti_2=df.drop(kashti_1.index)
kashti_2.shape
# Out:
# (445, 15)

# %%
kashti_1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 862         1       1  female  48.0      0      0  25.9292        S   First
# 223         0       3    male   NaN      0      0   7.8958        S   Third
# 84          1       2  female  17.0      0      0  10.5000        S  Second
# 680         0       3  female   NaN      0      0   8.1375        Q   Third
# 535         1       2  female   7.0      0      2  26.2500        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 153         0       3    male  40.5      0      2  14.5000        S   Third
# 396         0       3  female  31.0      0      0   7.8542        S   Third
# 612         1       3  female   NaN      1      0  15.5000        Q   Third
# 304         0       3    male   NaN      0      0   8.0500        S   Third
# 200         0       3    male  28.0      0      0   9.5000        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
kashti_2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 15          1       2  female  55.0      0      0  16.0000        S  Second
# 18          0       3  female  31.0      1      0  18.0000        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # Join Two data sets

# %%
df_1=kashti_1.append(kashti_2)
df_1.shape

# %% [markdown]
# # Filtering The data

# %%
df.head()
df.sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
# if you check the data
df[(df.sex=="female")]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[(df.embark_town=="Southampton") &
   (df.sex=="female")]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 11          1       1  female  58.0      0      0  26.5500        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 871         1       1  female  47.0      1      1  52.5542        S   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # Filtering the largest categories

# %%
# Filtration
df.age.value_counts().nlargest(3)
# Out:
# age
# 24.0    30
# 22.0    27
# 18.0    26
# Name: count, dtype: int64

# %% [markdown]
# # splitting a string into  multiple column

# %%
import pandas as pd

df=pd.DataFrame({'name': ['Alice humble', 'Bob jack', 'Charlie lie', 'David joob', 'Eve aventure'],
                 'age': [25, 30, 35, 40, 45],
                 'city': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']})
df
# Out:
#            name  age         city
# 0  Alice humble   25     New York
# 1      Bob jack   30  Los Angeles
# 2   Charlie lie   35      Chicago
# 3    David joob   40      Houston
# 4  Eve aventure   45      Phoenix

# %%
df.name.str.split(' ').expand=True
df
# Out:
#            name  age         city
# 0  Alice humble   25     New York
# 1      Bob jack   30  Los Angeles
# 2   Charlie lie   35      Chicago
# 3    David joob   40      Houston
# 4  Eve aventure   45      Phoenix

# %%
df.name.str.split(' ').head()
# Out:
# 0    [Alice, humble]
# 1        [Bob, jack]
# 2     [Charlie, lie]
# 3      [David, joob]
# 4    [Eve, aventure]
# Name: name, dtype: object

# %%
df=df[['first_name', 'last_name', 'age', 'city']]
df

# %% [markdown]
# # Aggregate the multiple column

# %%
import pandas as pd
import seaborn as sns
df=sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.groupby('sex').head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
df.groupby('who').count()
# Out:
#        survived  pclass  sex  age  sibsp  parch  fare  embarked  class  \
# who
# child        83      83   83   83     83     83    83        83     83
# man         537     537  537  413    537    537   537       537    537
# woman       271     271  271  218    271    271   271       269    271
#
#        adult_male  deck  embark_town  alive  alone
# who
# child          83    13           83     83     83
# man           537    99          537    537    537
# woman         271    91          269    271    271

# %%
df.groupby(['sex', 'pclass','who']).count()
# Out:
#                      survived  age  sibsp  parch  fare  embarked  class  \
# sex    pclass who
# female 1      child         3    3      3      3     3         3      3
#               woman        91   82     91     91    91        89     91
#        2      child        10   10     10     10    10        10     10
#               woman        66   64     66     66    66        66     66
#        3      child        30   30     30     30    30        30     30
#               woman       114   72    114    114   114       114    114
# male   1      child         3    3      3      3     3         3      3
#               man         119   98    119    119   119       119    119
#        2      child         9    9      9      9     9         9      9
#               man          99   90     99     99    99        99     99
#        3      child        28   28     28     28    28        28     28
#               man         319  225    319    319   319       319    319
#
# ...

# %% [markdown]
# # Select specific rows and columns

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df[['sex','class', 'who']]
# Out:
#         sex   class    who
# 0      male   Third    man
# 1    female   First  woman
# 2    female   Third  woman
# 3    female   First  woman
# 4      male   Third    man
# ..      ...     ...    ...
# 886    male  Second    man
# 887  female   First  woman
# 888  female   Third  woman
# 889    male   First    man
# 890    male   Third    man
#
# [891 rows x 3 columns]

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.describe().loc[['mean', 'std', 'min', '25%', '50%', '75%', 'max']]
# Out:
#       survived    pclass        age     sibsp     parch        fare
# mean  0.383838  2.308642  29.699118  0.523008  0.381594   32.204208
# std   0.486592  0.836071  14.526497  1.102743  0.806057   49.693429
# min   0.000000  1.000000   0.420000  0.000000  0.000000    0.000000
# 25%   0.000000  2.000000  20.125000  0.000000  0.000000    7.910400
# 50%   0.000000  3.000000  28.000000  0.000000  0.000000   14.454200
# 75%   1.000000  3.000000  38.000000  1.000000  0.000000   31.000000
# max   1.000000  3.000000  80.000000  8.000000  6.000000  512.329200

# %%
df.describe().loc['mean':'max']
# Out:
#       survived    pclass        age     sibsp     parch        fare
# mean  0.383838  2.308642  29.699118  0.523008  0.381594   32.204208
# std   0.486592  0.836071  14.526497  1.102743  0.806057   49.693429
# min   0.000000  1.000000   0.420000  0.000000  0.000000    0.000000
# 25%   0.000000  2.000000  20.125000  0.000000  0.000000    7.910400
# 50%   0.000000  3.000000  28.000000  0.000000  0.000000   14.454200
# 75%   1.000000  3.000000  38.000000  1.000000  0.000000   31.000000
# max   1.000000  3.000000  80.000000  8.000000  6.000000  512.329200

# %%
df.describe().loc['min':'max']
# Out:
#      survived  pclass     age  sibsp  parch      fare
# min       0.0     1.0   0.420    0.0    0.0    0.0000
# 25%       0.0     2.0  20.125    0.0    0.0    7.9104
# 50%       0.0     3.0  28.000    0.0    0.0   14.4542
# 75%       1.0     3.0  38.000    1.0    0.0   31.0000
# max       1.0     3.0  80.000    8.0    6.0  512.3292

# %% [markdown]
# # Mean solution

# %%
df.survived.mean()
# Out:
# np.float64(0.3838383838383838)

# %%
df.groupby('sex').survived.mean()
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %%
df.groupby(['sex','who']).survived.mean()
# Out:
# sex     who
# female  child    0.651163
#         woman    0.756458
# male    child    0.525000
#         man      0.163873
# Name: survived, dtype: float64

# %% [markdown]
# # continous data in categorical data

# %%
pd.cut(df.age, bins=[0, 18, 35, 60, 100], labels=['child', 'young adult', 'adult', 'senior'])
# Out:
# 0      young adult
# 1            adult
# 2      young adult
# 3      young adult
# 4      young adult
#           ...
# 886    young adult
# 887    young adult
# 888            NaN
# 889    young adult
# 890    young adult
# Name: age, Length: 891, dtype: category
# Categories (4, object): ['child' < 'young adult' < 'adult' < 'senior']

# %%
df['new_age_group']=pd.cut(df.age, bins=[0, 18, 35, 60, 100], labels=['child', 'young adult', 'adult', 'senior'])
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone new_age_group
# 0    man        True  NaN  Southampton    no  False   young adult
# 1  woman       False    C    Cherbourg   yes  False         adult
# 2  woman       False  NaN  Southampton   yes   True   young adult
# 3  woman       False    C  Southampton   yes  False   young adult
# 4    man        True  NaN  Southampton    no   True   young adult

# %% [markdown]
# # transpose of the dataframe

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(np.random.rand(100,15),columns=[f'col_{i}' for i in range(1,16)])
df
# Out:
#        col_1     col_2     col_3     col_4     col_5     col_6     col_7  \
# 0   0.494756  0.791184  0.555991  0.796530  0.395134  0.296522  0.408725
# 1   0.801602  0.383801  0.233681  0.285021  0.725973  0.283995  0.421616
# 2   0.760201  0.829384  0.623569  0.461484  0.025958  0.211925  0.690768
# 3   0.281561  0.797997  0.710064  0.674515  0.085321  0.400816  0.640410
# 4   0.615155  0.995602  0.475964  0.578330  0.993414  0.910386  0.732554
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.192150  0.070473  0.461142  0.558759  0.695461  0.258246  0.188588
# 96  0.711253  0.031178  0.696430  0.887741  0.659047  0.193889  0.361722
# 97  0.123738  0.460648  0.737660  0.877162  0.896435  0.425346  0.038697
# 98  0.667572  0.653532  0.718744  0.386436  0.850075  0.760652  0.553934
# 99  0.424949  0.604821  0.630697  0.878605  0.395350  0.754359  0.989084
#
#        col_8     col_9    col_10    col_11    col_12    col_13    col_14  \
# ...

# %%
df.T
# Out:
#               0         1         2         3         4         5         6   \
# col_1   0.494756  0.801602  0.760201  0.281561  0.615155  0.197111  0.291815
# col_2   0.791184  0.383801  0.829384  0.797997  0.995602  0.497825  0.327375
# col_3   0.555991  0.233681  0.623569  0.710064  0.475964  0.668419  0.526172
# col_4   0.796530  0.285021  0.461484  0.674515  0.578330  0.052534  0.089694
# col_5   0.395134  0.725973  0.025958  0.085321  0.993414  0.292926  0.480737
# col_6   0.296522  0.283995  0.211925  0.400816  0.910386  0.839448  0.170578
# col_7   0.408725  0.421616  0.690768  0.640410  0.732554  0.002222  0.462526
# col_8   0.507782  0.115610  0.129694  0.136171  0.099543  0.003967  0.414695
# col_9   0.814703  0.356044  0.392166  0.364932  0.806314  0.544785  0.200466
# col_10  0.320047  0.839242  0.891400  0.738831  0.002966  0.214703  0.097720
# col_11  0.738854  0.899405  0.619924  0.883743  0.280484  0.408842  0.191807
# ...

# %% [markdown]
# # Reshaping Of Dataframe

# %%
df.melt()
# Out:
#      variable     value
# 0       col_1  0.494756
# 1       col_1  0.801602
# 2       col_1  0.760201
# 3       col_1  0.281561
# 4       col_1  0.615155
# ...       ...       ...
# 1495   col_15  0.239373
# 1496   col_15  0.534849
# 1497   col_15  0.214278
# 1498   col_15  0.842799
# 1499   col_15  0.340945
#
# [1500 rows x 2 columns]

# %%
import seaborn as sns
sns.barplot(x='time', y='pulse', hue='kind', data=sns.load_dataset('exercise'))
# Out:
# <Axes: xlabel='time', ylabel='pulse'>
